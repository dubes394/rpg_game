# %% [markdown]
# # File Handling
# #### 1. Open a file
# #### 2. Read/write file
# #### 3. close the file

# %%
f = open('sample.txt', "w")
f.write("Hello world")
f.close()

# %%
f = open('sample1.txt', 'w')
f.write('hello world')
f.write('\nhow are you mf!')
f.close()

# %%
f= open('sample.txt', 'w')
f.write('salman khan ')
f.close()

# %%
f = open('/home/capecrusader/repos/python/11_file_handling/sample1.txt', 'a')
f.write("\nI am fine! loser")
f.close()

# %%
L = ['hello\n', 'welcome\n', 'what do you need\n', "bread\n"]

f = open("/home/capecrusader/repos/python/11_file_handling/sample1.txt", 'w')
f.writelines(L)
f.close()

# %%
f = open("sample.txt", 'r')
s = f.read()
print(s)
# Out:
# salman khan

# %%
f = open("sample1.txt", 'r')
print(f.readline(), end="")
print(f.readline(), end="")
# Out:
# hello
# welcome

# %% [markdown]
# # Using Context manager "with"

# %%
with open("sample1.txt", 'w') as f:
    f.write("GSP")

# %%
with open("sample.txt", "r") as f:
    print(f.read())
# Out:
# salman khan

# %%
with open("sample.txt", "r") as f:
    print(f.read(10))
# Out:
# salman kha

# %%
big_L = ["hello world " for i in range(1000)]

with open("big.txt", 'w') as f:
    f.writelines(big_L)

# %%
with open("big.txt", 'r') as f:
    
    chunk_size = 10
    
    while len(f.read(chunk_size)) > 0:
        print(f.read(chunk_size))
        print(f.tell())
        f.read(chunk_size)
# Out:
# d hello wo
# 20
# o world he
# 50
# d hello wo
# 80
# o world he
# 110
# d hello wo
# 140
# o world he
# 170
# d hello wo
# 200
# o world he
# 230
# d hello wo
# 260
# o world he
# 290
# d hello wo
# 320
# o world he
# 350
# d hello wo
# 380
# o world he
# 410
# d hello wo
# 440
# o world he
# 470
# d hello wo
# 500
# o world he
# 530
# d hello wo
# 560
# o world he
# 590
# d hello wo
# 620
# o world he
# 650
# d hello wo
# 680
# o world he
# 710
# d hello wo
# 740
# o world he
# 770
# d hello wo
# 800
# o world he
# 830
# d hello wo
# 860
# o world he
# 890
# d hello wo
# 920
# o world he
# 950
# d hello wo
# 980
# o world he
# 1010
# d hello wo
# 1040
# o world he
# 1070
# d hello wo
# 1100
# o world he
# 1130
# d hello wo
# 1160
# o world he
# 1190
# d hello wo
# 1220
# o world he
# 1250
# d hello wo
# 1280
# o world he
# 1310
# d hello wo
# 1340
# o world he
# 1370
# d hello wo
# 1400
# o world he
# 1430
# d hello wo
# 1460
# o world he
# 1490
# d hello wo
# 1520
# o world he
# ...

# %%
with open("sample.txt", "r") as f:
    print(f.read(10))
    print(f.tell())
# Out:
# salman kha
# 10

# %%
with open('sample.txt', 'r') as f:
    print(f.read(10))
    print(f.tell())
    f.seek(15)
    print(f.read(10))
# Out:
# Hi
# hello
# h
# 10
# e you

# %%
with open('sample.txt', 'w') as f:
    f.write('Hello')
    f.seek(0)
    f.write('Xa')

# %% [markdown]
# ## Problems with working in text mode

# %%
with open('/home/capecrusader/repos/python/11_file_handling/Sri_Yantra_Correct_Colors_Johari_1974.jpg', 'r') as f:
    f.read()
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# Cell In[10], line 2
#       1 with open('/home/capecrusader/repos/python/11_file_handling/Sri_Yantra_Correct_Colors_Johari_1974.jpg', 'r') as f:
# ----> 2     f.read()
#
# File <frozen codecs>:325, in BufferedIncrementalDecoder.decode(self, input, final)
#     322 'Could not get source, probably due dynamically evaluated source code.'
#
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0xff in position 0: invalid start byte

# %%
with open('/home/capecrusader/repos/python/11_file_handling/Sri_Yantra_Correct_Colors_Johari_1974.jpg', 'rb') as f:
    with open('/home/capecrusader/repos/python/11_file_handling/Sri_Yantra_Correct_Colors_Johari_1974_copy.jpg', 'wb' ) as wf:
        wf.write(f.read())

# %%
with open('sample.txt', 'r') as f:
    f.write(5)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[12], line 2
#       1 with open('sample.txt', 'r') as f:
# ----> 2     f.write(5)
#
# TypeError: write() argument must be str, not int

# %% [markdown]
# # Serialization and Deserialization

# %%
# serialization using json
import json

L = [1,2,3,4]

with open('demo.json', 'w') as f:
    json.dump(L,f, indent =4)

# %%
import json 

with open('demo.json', 'r') as f:
    d = json.load(f)
    print(d)
    print(type(d))
# Out:
# [1, 2, 3, 4]
# <class 'list'>

# %%
import json

t = (1,2,3,4)

with open('demo.json', 'w') as f:
    json.dump(t,f)

# %%
class Person:
    def __init__(self, fname, lname, age, gender):
        self.fname = fname
        self.lname = lname
        self.age = age
        self.gender = gender

# %%
person = Person("kunal", "dubey", 29, "male")

# %%
import json 

def show_object(person):
    if isinstance(person, Person):
        return "{} {} age --> {} gender --> {}".format(person.fname, person.lname, person.age, person.gender)

with open("demo.json", 'w') as f:
    json.dump(person, f, default= show_object)

# %%
import json

def show_object(person):
  if isinstance(person,Person):
    return {'name':person.fname + ' ' + person.lname,'age':person.age,'gender':person.gender}

with open('demo.json','w') as f:
  json.dump(person,f,default=show_object,indent=4)

# %%
import json

with open('demo.json', 'r') as f:
    d = json.load(f)
    print(d)
    print(type(d))
# Out:
# {'name': 'kunal dubey', 'age': 29, 'gender': 'male'}
# <class 'dict'>

# %%
class Person:

  def __init__(self,name,age):
    self.name = name
    self.age = age

  def display_info(self):
    print('Hi my name is',self.name,'and I am ',self.age,'years old')

# %%
person = Person('nitish', 33)

# %%
import pickle
with open('person.pkl','wb') as f:
  pickle.dump(person,f)
