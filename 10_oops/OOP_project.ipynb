# %%
# !pip install nlpcloud
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting nlpcloud
#   Downloading nlpcloud-1.1.47-py3-none-any.whl.metadata (1.1 kB)
# Requirement already satisfied: requests in /usr/lib/python3.14/site-packages (from nlpcloud) (2.33.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/lib/python3.14/site-packages (from requests->nlpcloud) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/lib/python3.14/site-packages (from requests->nlpcloud) (3.18)
# Requirement already satisfied: urllib3<3,>=1.26 in /usr/lib/python3.14/site-packages (from requests->nlpcloud) (2.7.0)
# Downloading nlpcloud-1.1.47-py3-none-any.whl (3.9 kB)
# Installing collected packages: nlpcloud
# Successfully installed nlpcloud-1.1.47

# %%
import nlpcloud

client = nlpcloud.Client("llama-3-1-405b", "4f246fdb23baafc5ebd26263feafb1bd433de730", gpu=True)
client.entities(
    """John Doe started learning Javascript when he was 15 years old. After a couple of years he switched to Python and starter learning low level programming. He is now a Go expert at Google.""",
    searched_entity="programming languages"
)
# Out:
# {'entities': [{'start': 26,
#    'end': 36,
#    'type': 'programming languages',
#    'text': 'Javascript'},
#   {'start': 102,
#    'end': 108,
#    'type': 'programming languages',
#    'text': 'Python'},
#   {'start': 165, 'end': 167, 'type': 'programming languages', 'text': 'Go'}]}

# %%
class NLPApp:
    
    def __init__(self):
        
        self.__database = {}
        self.__first_menu()
        
    def __first_menu(self):
        
        first_input = input("""
        Hi! How would you like to proceed?
        1. Not a member? Register
        2. Akready a member? Login
        3. Don't know ? Nikal BKL       
              """)
        
        if first_input == "1":
            self.__register()
        elif first_input == "2":
            self.__login()   
        else:
            exit()
              
    def __register(self):
        print("Register")    
    
    def __login(self):
        print("Login")
        

obj = NLPApp()
# Out:
# Login
