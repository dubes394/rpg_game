# %%
# !pip install nlpcloud
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...

# %%
import nlpcloud

client = nlpcloud.Client("llama-3-1-405b", "4f246fdb23baafc5ebd26263feafb1bd433de730", gpu=True)
client.entities(
    """John Doe started learning Javascript when he was 15 years old. After a couple of years he switched to Python and starter learning low level programming. He is now a Go expert at Google.""",
    searched_entity="programming languages"
)

# client = nlpcloud.Client("gpt-oss-120b", "4f246fdb23baafc5ebd26263feafb1bd433de730", gpu=True)
# client.sentiment(
#     """I hate convoluted products with poor documentation. I see such products all the time. But NLP Cloud is not like that!""",
#     target="NLP Cloud"
# )
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# File ~/.local/lib/python3.14/site-packages/nlpcloud/__init__.py:185, in Client.entities(self, text, searched_entity)
#     184 try:
# --> 185     r.raise_for_status()
#     186 except HTTPError as err:
#
# File /usr/lib/python3.14/site-packages/requests/models.py:1028, in Response.raise_for_status(self)
#    1027 if http_error_msg:
# -> 1028     raise HTTPError(http_error_msg, response=self)
#
# HTTPError: 429 Client Error: Too Many Requests for url: https://api.nlpcloud.io/v1/gpu/llama-3-1-405b/entities
#
# During handling of the above exception, another exception occurred:
#
# HTTPError                                 Traceback (most recent call last)
# Cell In[9], line 4
#       1 import nlpcloud
#       2
#       3 client = nlpcloud.Client("llama-3-1-405b", "4f246fdb23baafc5ebd26263feafb1bd433de730", gpu=True)
# ...

# %%
import nlpcloud
class NLPApp:
    
    def __init__(self):
        
        self.__database = {}
        self.__first_menu()
        
    def __first_menu(self):
        
        first_input = input("""
        Hi! How would you like to proceed?
        1. Not a member? Register
        2. Akready a member? Login
        3. Don't know ? Nikal BKL       
              """)
        
        if first_input == "1":
            self.__register()
        elif first_input == "2":
            self.__login()   
        else:
            exit()

    def __second_menu(self):
        
        second_input = input("""
        Hi! How would you like to proceed?
        1. NER
        2. Language detection
        3. Sentimental Analysis
        4. exit   
              """)
        
        if second_input == "1":
            self.__ner()
        elif second_input == "2":
            self.__language_detection()   
        elif second_input == "3":
            self.__sentimental_analysis()
        else:            
            exit()
              
    def __register(self):
        name = input("Enter name")
        email = input("enter email")    
        password= input("enter password")
        
        if email in self.__database:
            print("email exists")
        else:
            self.__database[email] = [name, password]
            print("Registration done!! Now login")   
            print(self.__database)
            self.__first_menu()  
              
    def __login(self):
        email = input("Enter email")
        password = input("Enter password")
        
        if email in self.__database:
            if self.__database[email][1] == password:
                print('Login Successful!!')
                self.__second_menu()
            else:
                print("wrong passsword. Try again!!")
                self.__login()
        else:
            print(f"This email does nbot registered")
            self.__first_menu
        
    def __ner(self):
        paragraph = input(f"Enter the paragraph")
        search_term = input(f"What would you like to search??")
        
        client = nlpcloud.Client("llama-3-1-405b", "4f246fdb23baafc5ebd26263feafb1bd433de730", gpu=True)
        response = client.entities(paragraph ,searched_entity= search_term)
        
        print(response)
        
    def __sentimental_analysis(self):
        paragraph = input("enter your paragraph")
        
        client = nlpcloud.Client("gpt-oss-120b", "4f246fdb23baafc5ebd26263feafb1bd433de730", gpu=True)
        repsonse = client.sentiment(paragraph)

        
obj = NLPApp()
# Out:
# Registration done!! Now login
# {'kunal@email.com': ['kunal', '1234']}
# Login Successful!!
# {'entities': [{'start': 26, 'end': 36, 'type': 'programming languages', 'text': 'Javascript'}, {'start': 102, 'end': 108, 'type': 'programming languages', 'text': 'Python'}, {'start': 165, 'end': 167, 'type': 'programming languages', 'text': 'Go'}]}

# %%
d["scored_labels"]

# %%
L = []
for i in d['scored label']:
    L.append()
