# %% [markdown]
# ##REVISE OOPS
#
# #class are blueprint and objects are instance of that class.
# #class car hai aur tata sierra is instance

# %%
class Atm:

    def __init__(self):
        self.pin = ""
        self.balance = 0
        self.menu()

    def menu(self):
        user_input = input("""
Hi how can I help you?
1. Press 1 to create pin
2. Press 2 to change pin
3. Press 3 to check balance
4. Press 4 to withdraw
5. Anything else to exit
""")

        if user_input == "1":
            self.create_pin()

        elif user_input == "2":
            self.change_pin()

        elif user_input == "3":
            self.check_balance()

        elif user_input == "4":
            self.withdraw()

        else:
            exit()

    def create_pin(self):
        user_pin = input("Enter your pin: ")
        self.pin = user_pin

        user_balance = int(input("Enter balance: "))
        self.balance = user_balance

        print("PIN created successfully")
        self.menu()
        
    def change_pin(self):
        old_pin = input("Enter old pin")
        
        if old_pin == self.pin:
            new_pin = input("enter new pin")
            self.pin = new_pin
            print("PIN changed")
            self.menu()
        else:
            print("error")
            self.menu()
            
    def check_balance(self):
        user_pin = input("enter the PIN") 
        
        if user_pin == self.pin:
            print(f"Your balance is {self.balance}")
        else:
            print(f"Error!!!")
        self.menu()
        
    def withdraw(self):
        user_pin = input("Enter your PIN")
        
        if user_pin == self.pin:
            print(f"Your balance is{self.balance}")
        else:
            print(f"Error!!!")
        
        user_balance = int(input("Enter the amount you want to withdraw"))
        
        if user_balance <= self.balance:
            withdrawal_amount = self.balance - user_balance
            print(f"Amount withdraw is {user_balance}. Your new balance is {withdrawal_amount}")
        else:
            print("Error")
        self.menu()

# %%
obj = Atm()
# Out:
# PIN created successfully
# Your balance is10000
# Amount withdraw is 1000. Your new balance is 9000
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 obj = Atm()
#
# Cell In[6], line 6, in Atm.__init__(self)
#       3     def __init__(self):
#       4         self.pin = ""
#       5         self.balance = 0
# ----> 6         self.menu()
#
# Cell In[6], line 19, in Atm.menu(self)
#      15 5. Anything else to exit
#      16 """)
#      17
#      18         if user_input == "1":
# ---> 19             self.create_pin()
#      20
#      21         elif user_input == "2":
#      22             self.change_pin()
#
# Cell In[6], line 41, in Atm.create_pin(self)
#      37         user_balance = int(input("Enter balance: "))
#      38         self.balance = user_balance
#      39
#      40         print("PIN created successfully")
# ---> 41         self.menu()
#
# Cell In[6], line 28, in Atm.menu(self)
#      24         elif user_input == "3":
#      25             self.check_balance()
#      26
#      27         elif user_input == "4":
# ---> 28             self.withdraw()
#      29
#      30         else:
#      31             exit()
#
# Cell In[6], line 79, in Atm.withdraw(self)
#      75             withdrawal_amount = self.balance - user_balance
#      76             print(f"Amount withdraw is {user_balance}. Your new balance is {withdrawal_amount}")
#      77         else:
#      78             print("Error")
# ---> 79         self.menu()
#
# Cell In[6], line 9, in Atm.menu(self)
#       8     def menu(self):
# ----> 9         user_input = input("""
#      10 Hi how can I help you?
#      11 1. Press 1 to create pin
#      12 2. Press 2 to change pin
#
# File ~/.local/lib/python3.14/site-packages/ipykernel/kernelbase.py:1403, in Kernel.raw_input(self, prompt)
#    1401     msg = "raw_input was called, but this frontend does not support input requests."
#    1402     raise StdinNotImplementedError(msg)
# -> 1403 return self._input_request(
#    1404     str(prompt),
#    1405     self._get_shell_context_var(self._shell_parent_ident),
#    1406     self.get_parent("shell"),
#    1407     password=False,
#    1408 )
#
# File ~/.local/lib/python3.14/site-packages/ipykernel/kernelbase.py:1448, in Kernel._input_request(self, prompt, ident, parent, password)
#    1445 except KeyboardInterrupt:
#    1446     # re-raise KeyboardInterrupt, to truncate traceback
#    1447     msg = "Interrupted by user"
# -> 1448     raise KeyboardInterrupt(msg) from None
#    1449 except Exception:
#    1450     self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user
